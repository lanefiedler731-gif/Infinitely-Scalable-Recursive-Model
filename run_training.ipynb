# %%
# !HF_HUB_ENABLE_HF_TRANSFER=1 python3 train.py --config config.yaml --resume outputs/best_model.pt

from google.colab import drive
drive.mount('1ZEeeFX60ZWeKE5z1Rn_LnXc0pZLHPYvb')

# !cd /content/1ZEeeFX60ZWeKE5z1Rn_LnXc0pZLHPYvb/MyDrive/conversational_llm_trainer/ && HF_HUB_ENABLE_HF_TRANSFER=1 python3 train.py --config config.yaml --resume outputs/best_model.pt
